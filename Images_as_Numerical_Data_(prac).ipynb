# %% [markdown]
# <a href="https://colab.research.google.com/github/shaonsani/Udacity-Nano-Degree/blob/master/Images_as_Numerical_Data_(prac).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-a6b6a2e8-a8cc-40ea-a0ce-5b37910255bf" name="files[]" multiple disabled />
#      <output id="result-a6b6a2e8-a8cc-40ea-a0ce-5b37910255bf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving waymo_car.jpg to waymo_car (1).jpg
# ...

# %%
image = mpimg.imread('waymo_car.jpg')
print(image.shape)
gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
plt.imshow(gray_image,cmap='gray')
# Out:
# (427, 640, 3)

# %%
x = 180
y = 350
print(gray_image[y,x])
# Out:
# 30

# %%
min_val= np.amin(gray_image)
max_val = np.amax(gray_image)
print("min value {0} and max value {1}".format(min_val,max_val))
# Out:
# min value 2 and max value 255

# %%
my_image = np.array([[0,255,255,3,4,5],
                    [6,7,255,9,10,11],
                    [12,13,255,15,16,17],
                    [18,19,255,22,22,23],
                    [24,25,255,27,28,29],
                    [30,31,255,33,34,35]])
plt.imshow(my_image, cmap='gray')
